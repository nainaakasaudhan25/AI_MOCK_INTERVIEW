# %% [markdown]
# <a href="https://colab.research.google.com/github/nainaakasaudhan25/AI_MOCK_INTERVIEW/blob/main/HPC_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello HPC LAB")
# Out:
# Hello HPC LAB

# %%
a=3
b=2
addition=a+b
subtraction=a-b
multiplication=a*b
print("Addition:",addition)
print("Subtraction:",subtraction)
print("Multiplication:",multiplication)
# Out:
# Addition: 5
# Subtraction: 1
# Multiplication: 6
